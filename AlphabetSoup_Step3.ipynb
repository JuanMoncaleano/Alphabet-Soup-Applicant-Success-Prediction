# %%
pip install tensorflow

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
# !pip install keras-tuner

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\juank\OneDrive\Desktop\Everything\UofT\Modules\Module_21\deep-learning-challenge\AlphabetSoup_Step3.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/juank/OneDrive/Desktop/Everything/UofT/Modules/Module_21/deep-learning-challenge/AlphabetSoup_Step3.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.preprocessing import StandardScaler
#       <a href='vscode-notebook-cell:/c%3A/Users/juank/OneDrive/Desktop/Everything/UofT/Modules/Module_21/deep-learning-challenge/AlphabetSoup_Step3.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juank/OneDrive/Desktop/Everything/UofT/Modules/Module_21/deep-learning-challenge/AlphabetSoup_Step3.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> import tensorflow as tf
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\juank\OneDrive\Desktop\Everything\UofT\Modules\Module_21\deep-learning-challenge\AlphabetSoup_Step3.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/juank/OneDrive/Desktop/Everything/UofT/Modules/Module_21/deep-learning-challenge/AlphabetSoup_Step3.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juank/OneDrive/Desktop/Everything/UofT/Modules/Module_21/deep-learning-challenge/AlphabetSoup_Step3.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> application_df = application_df.drop(columns = ['EIN', 'NAME'])
#
# NameError: name 'application_df' is not defined

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_types = application_df['APPLICATION_TYPE'].value_counts()
app_types
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_types.iloc[8:].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_types = application_df['CLASSIFICATION'].value_counts()
class_types
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_types.loc[class_types > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_types.iloc[6:].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
#Check some other variables to drop from data
print(application_df['SPECIAL_CONSIDERATIONS'].value_counts())

application_df = application_df.drop(columns = ['SPECIAL_CONSIDERATIONS'])

application_df
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
# ...

# %%
#Check some other variables to drop from data
print(application_df['STATUS'].value_counts())

application_df = application_df.drop(columns = ['STATUS'])

application_df
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# ...

# %%
#Check some other variables to drop from data
print(application_df['INCOME_AMT'].value_counts())
application_df = application_df.drop(columns = ['INCOME_AMT'])
application_df
# Out:
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: INCOME_AMT, dtype: int64
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# ...

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = dummies['IS_SUCCESSFUL'].values
X = dummies.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Use Keras Tuner to optimize model

# %%
# Tuner Function
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=5,
        max_value=30,
        step=5), activation=activation, input_dim=32))
    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=5,
            max_value=30,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

    return nn_model

# %%
import keras_tuner as kt
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 56 Complete [00h 00m 49s]
# val_accuracy: 0.7257142663002014
#
# Best val_accuracy So Far: 0.7293294668197632
# Total elapsed time: 00h 23m 19s

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 30,
#  'num_layers': 3,
#  'units_0': 15,
#  'units_1': 30,
#  'units_2': 20,
#  'units_3': 20,
#  'units_4': 25,
#  'units_5': 10,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '0044'}

# %%
second_best_hyper = tuner.get_best_hyperparameters(2)[1]
second_best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 15,
#  'num_layers': 4,
#  'units_0': 25,
#  'units_1': 20,
#  'units_2': 25,
#  'units_3': 10,
#  'units_4': 15,
#  'units_5': 20,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '0015'}

# %%
third_best_hyper = tuner.get_best_hyperparameters(3)[2]
third_best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 15,
#  'num_layers': 2,
#  'units_0': 30,
#  'units_1': 25,
#  'units_2': 30,
#  'units_3': 15,
#  'units_4': 5,
#  'units_5': 10,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5592 - accuracy: 0.7293 - 589ms/epoch - 2ms/step
# Loss: 0.5591617822647095, Accuracy: 0.7293294668197632

# %% [markdown]
# ## Trying with best model from Keras Tuner

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
hidden_nodes_first = 30
hidden_nodes_second = 15
hidden_nodes_third = 30
hidden_nodes_fourth = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_first, input_dim = input_features, activation = "tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_second, activation = "tanh"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_third, activation = "tanh"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_fourth, activation = "tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 30)                990
#
#  dense_11 (Dense)            (None, 15)                465
#
#  dense_12 (Dense)            (None, 30)                480
#
#  dense_13 (Dense)            (None, 20)                620
#
#  dense_14 (Dense)            (None, 1)                 21
#
# ...
# Total params: 2576 (10.06 KB)
# Trainable params: 2576 (10.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5755 - accuracy: 0.7172
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5632 - accuracy: 0.7250
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5610 - accuracy: 0.7257
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7256
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7266
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7267
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7263
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7271
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7269
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5556 - accuracy: 0.7304 - 505ms/epoch - 2ms/step
# Loss: 0.5555531978607178, Accuracy: 0.7303789854049683

# %%
# Export our model to HDF5 file
# https://stackoverflow.com/questions/50447222/google-colaboratory-keras-save-model-in-hdf5-file-format-and-download-it-to-l

# from google.colab import files
# files.download("AlphabetSoupCharityOptimize1.h5")

# !pip install h5py

nn.save('AlphabetSoupCharityOptimize1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Trying original model with reduced datatset
#
# ---

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
hidden_nodes_first = 8
hidden_nodes_second = 4
# hidden_nodes_third = 5
# hidden_nodes_fourth = 9

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_first, input_dim = input_features, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_second, activation = "relu"))
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_third, activation = "tanh"))
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_fourth, activation = "tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_25 (Dense)            (None, 8)                 264
#
#  dense_26 (Dense)            (None, 4)                 36
#
#  dense_27 (Dense)            (None, 1)                 5
#
# ...
# Total params: 305 (1.19 KB)
# Trainable params: 305 (1.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6253 - accuracy: 0.6765
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5688 - accuracy: 0.7223
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7249
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7252
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5594 - accuracy: 0.7262
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5590 - accuracy: 0.7252
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5583 - accuracy: 0.7260
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5578 - accuracy: 0.7257
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5575 - accuracy: 0.7260
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5591 - accuracy: 0.7293 - 541ms/epoch - 2ms/step
# Loss: 0.5591439604759216, Accuracy: 0.7293294668197632

# %%
nn.save('AlphabetSoupCharityOptimize2.h5')

# %% [markdown]
# ## Third try with Keras Tuner second-best model
#
# > Indented block

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
hidden_nodes_first = 15
hidden_nodes_second = 30
hidden_nodes_third = 25
# hidden_nodes_fourth = 7

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_first, input_dim = input_features, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_second, activation = "relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_third, activation = "relu"))
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_fourth, activation = "tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 15)                495
#
#  dense_19 (Dense)            (None, 30)                480
#
#  dense_20 (Dense)            (None, 25)                775
#
#  dense_21 (Dense)            (None, 1)                 26
#
# ...
# Total params: 1776 (6.94 KB)
# Trainable params: 1776 (6.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5822 - accuracy: 0.7149
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7249
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7242
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5585 - accuracy: 0.7268
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7266
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5582 - accuracy: 0.7268
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5577 - accuracy: 0.7256
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5573 - accuracy: 0.7257
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7276
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5603 - accuracy: 0.7300 - 486ms/epoch - 2ms/step
# Loss: 0.5602536797523499, Accuracy: 0.7300291657447815

# %%
nn.save('AlphabetSoupCharityOptimize3.h5')
